# %% [markdown]
# # Test that opencv is installed properly

# %%
import matplotlib as mpl
import numpy as np
import random
from matplotlib import pyplot as plt

# %%
import cv2 as cv

# %%
cv.__version__
# Out:
# '4.0.1'

# %%
cv.__file__
# Out:
# '/Users/lambert/virtualenv/v1/lib/python2.7/site-packages/cv2/cv2.so'

# %%
# %matplotlib notebook

# %%
from IPython.core.display import HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
img = cv.imread('/Users/Lambert/Pictures/IMG_5107.JPG')  # Note it will be read in BGR format - that's how OpenCV does things

# %%
plt.figure()
plt.imshow(img)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
img2 = img[...,::-1]   # This is the easy way to reorder the bands to display with matplotlib.

# %%
def lshow(img, vmax=None):
    """
    Lambert's version of imshow.
    """
    f,ax = plt.subplots()
    cmap = None
    if (len(img.shape) == 2) or (img.shape[2] == 1):
        cmap = 'viridis'
    him = ax.imshow(img, cmap=cmap, vmax=vmax)
    if img.dtype != bool:
        f.colorbar(him, ax=ax)
    return ax

# %%
ax = lshow(img2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
img.shape
# Out:
# (2576, 1932, 3)

# %%
def clear_graphics(ax):
    if ax.lines:
        [lin.remove() for lin in reversed(ax.lines)]
    # Can do similar removals with ax.patches, and with objects returned by ax.get_children() such
    # as instances of mpl.text.Annotation and mpl.collections.PathCollection

# %%
def random_lines(ax, num_lines, bound):
    for i in range(num_lines):
        x1 = random.randint(0,bound)
        x2 = random.randint(0,bound)
        y1 = random.randint(0,bound)
        y2 = random.randint(0,bound)
        mlin = mpl.lines.Line2D((x1, x2), (y1, y2), marker='x')
        ax.add_line(mlin)

# %%
clear_graphics(ax)
random_lines(ax, 5, 1000)
